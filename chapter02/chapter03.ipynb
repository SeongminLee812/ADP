# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
wine_load = load_wine()
wine = pd.DataFrame(wine_load.data, columns = wine_load.feature_names)
wine['Class'] = wine_load.target
wine['Class'] = wine['Class'].map({0:'class_0', 1:'class_1', 2:'class_2'})

wine_type = wine['Class'].value_counts()
wine_type
# Out:
# class_1    71
# class_0    59
# class_2    48
# Name: Class, dtype: int64

# %%
plt.bar(wine_type.index, wine_type.values, width=0.8, bottom=None, align='center')
plt.show()

# %%
plt.title('Wine alcohol histogram')
plt.hist('alcohol', bins=8, range=(wine['alcohol'].min(), wine['alcohol'].max()), color='purple', data=wine)
plt.show()

# %%
from sklearn.datasets import load_iris

iris = load_iris()
iris = pd.DataFrame(iris.data, columns = iris.feature_names)
iris['class'] = load_iris().target
iris['class'] = iris['class'].map({0:'Setosa', 1:'Versicolor', 2:'Virginica'})

plt.boxplot(iris.drop(columns='class'))
plt.show()

# %%
plt.boxplot(iris['sepal width (cm)'], whis=1.5)
plt.title('sepal width (cm)')
plt.show()

# %%
iris[['sepal width (cm)', 'class']].boxplot(by='class')
plt.show()

# %%
import seaborn as sns
sns.boxplot(x='class', y='sepal width (cm)', data=iris)
plt.show()

# %%
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', data=iris, 
               hue='class', style='class')
plt.show()

# %%
def linear_func(x):
    return 2 * x + 1

X = iris['sepal length (cm)']
plt.plot(X, linear_func(X), linestyle='dashed')
plt.show()

# %%
import numpy as np

# %%
X, Y = iris['sepal length (cm)'], iris['petal length (cm)']
b1, b0 = np.polyfit(X, Y, 1)
plt.scatter(x=X, y=Y, alpha = 0.5)
plt.plot(X, b1*X + b0, color='red')
plt.show()

# %%
iris2 = iris.sort_values(by='sepal length (cm)')
X, Y = iris2['sepal length (cm)'], iris2['petal length (cm)']
b2, b1, b0 = np.polyfit(X, Y, 2)
plt.scatter(x=X, y=Y, alpha = 0.5)
plt.plot(X, b0 + b1*X+ b2*X**2, color='red')
plt.show()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(iris, alpha=0.5, figsize=(8, 8), diagonal='hist')
plt.show()

# %%
sns.pairplot(iris, diag_kind='auto', hue='class')
plt.show()

# %%
iris_corr = iris.drop(columns='class').corr(method='pearson')
sns.heatmap(iris_corr, xticklabels=iris_corr.columns, yticklabels=iris_corr.columns, cmap='RdBu_r', annot=True)
plt.show()

# %%
iris_corr
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
from pandas_profiling import ProfileReport
ProfileReport(iris)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/wv/bnpq1s_d23qg2x2m69xg48gc0000gn/T/ipykernel_8785/108035381.py in <module>
# ----> 1 from pandas_profiling import ProfileReport
#       2 ProfileReport(iris)
#
# ~/opt/anaconda3/envs/ADP/lib/python3.7/site-packages/pandas_profiling/__init__.py in <module>
#      16
#      17 from pandas_profiling.config import config
# ---> 18 from pandas_profiling.controller import pandas_decorator
#      19 import pandas_profiling.view.templates as templates
#      20 from pandas_profiling.model.describe import describe as describe_df
#
# ~/opt/anaconda3/envs/ADP/lib/python3.7/site-packages/pandas_profiling/controller/pandas_decorator.py in <module>
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 3 from pandas_profiling.__init__ import ProfileReport
#       4
#       5
#
# ~/opt/anaconda3/envs/ADP/lib/python3.7/site-packages/pandas_profiling/__init__.py in <module>
#      17 from pandas_profiling.config import config
#      18 from pandas_profiling.controller import pandas_decorator
# ---> 19 import pandas_profiling.view.templates as templates
#      20 from pandas_profiling.model.describe import describe as describe_df
#      21 from pandas_profiling.view.notebook import display_notebook_iframe
#
# ~/opt/anaconda3/envs/ADP/lib/python3.7/site-packages/pandas_profiling/view/templates.py in <module>
#       3 from jinja2 import Environment, PackageLoader
#       4
# ----> 5 from pandas_profiling.view.formatters import (
#       6     fmt_percent,
#       7     fmt_bytesize,
#
# ~/opt/anaconda3/envs/ADP/lib/python3.7/site-packages/pandas_profiling/view/formatters.py in <module>
#       1 """Formatters are utilities for formatting numbers and certain strings"""
# ----> 2 from jinja2.utils import escape
#       3 import numpy as np
#       4
#       5
#
# ImportError: cannot import name 'escape' from 'jinja2.utils' (/Users/iseongmin/opt/anaconda3/envs/ADP/lib/python3.7/site-packages/jinja2/utils.py)
